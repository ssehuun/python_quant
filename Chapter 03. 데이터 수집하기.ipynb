# %% [markdown]
# # Chapter 03. 데이터 수집하기

# %%
import requests
import bs4

naver_url = "https://www.naver.com"
naver_response = requests.get(naver_url)
# naver_response.text

# %%
import bs4

naver_bs = bs4.BeautifulSoup(naver_response.text, 'lxml')
naver_bs.find('span', class_='ah_k')
# find는 같은 class 속성들이 있다면 그중에 맨 첫 번째 것만 가져옴.
# 만약 class 속성을 지정해주지 않는다면 이 페이지에 있는 모든 span 태그 중 첫번쨰 코드를 가져옴

# %%
result = naver_bs.find('span')
result.text
# Out:
# '뉴스스탠드 바로가기'

# %%
naver_bs.find_all('span')
# Out:
# [<span>뉴스스탠드 바로가기</span>,
#  <span>주제별캐스트 바로가기</span>,
#  <span>타임스퀘어 바로가기</span>,
#  <span>쇼핑캐스트 바로가기</span>,
#  <span>로그인 바로가기</span>,
#  <span>옆에서 쓰-윽 꺼내보는 재미! </span>,
#  <span>다운로드</span>,
#  <span class="blind">NAVER whale</span>,
#  <span class="blind">네이버</span>,
#  <span class="blind">쥬니어네이버</span>,
#  <span class="blind">해피빈</span>,
#  <span class="blind">검색</span>,
#  <span class="ico_search_submit"></span>,
#  <span class="ico_keyboard"></span>,
#  <span class="blind">입력도구</span>,
#  <span class="blind _text">자동완성/최근검색어 펼치기</span>,
#  <span class="ico_arr"></span>,
#  <span class="desc">
#  <span class="plus_txt _plusTxt">시간대와 관심사에 맞춘 <em class="txt">컨텍스트 자동완성</em></span>
#  <a class="spat ico_info _plusHelp" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=16658" onclick="__atcmpCR(event, this, 'plus.help', '','','');" target="_blank"><span class="blind">도움말 보기</span></a>
#  </span>,
#  <span class="plus_txt _plusTxt">시간대와 관심사에 맞춘 <em class="txt">컨텍스트 자동완성</em></span>,
#  <span class="blind">도움말 보기</span>,
#  <span class="switch _plus_btn">
#  <a class="btn_turnon active" href="#" onclick="__atcmpCR(event, this, 'plus.use', '','','');">ON<span class="blind">선택됨</span></a>
#  <a class="btn_turnoff" href="#" onclick="__atcmpCR(event, this, 'plus.unuse', '','','');">OFF</a>
#  </span>,
#  <span class="blind">선택됨</span>,
#  <span class="fl"><a class="_help" href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a><span class="atcmp_bar"></span><a class="report" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=605&amp;categoryNo=18215" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a></span>,
#  <span class="atcmp_bar"></span>,
#  <span><em><a class="hisoff" href="javascript:;">검색어저장 켜기</a><span class="atcmp_bar"></span></em><a class="funoff" href="javascript:;">자동완성 끄기</a></span>,
#  <span class="atcmp_bar"></span>,
#  <span class="atcmp_helper _help_tooltip1">기능을 다시 켤 때는 <em class="ico_search spat">자동완성 펼치기</em>을 클릭하세요</span>,
#  <span class="fl"><a class="_help" href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a><span class="atcmp_bar"></span><a class="report" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=605&amp;categoryNo=18215" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a></span>,
#  <span class="atcmp_bar"></span>,
#  <span><em><a class="hisoff" href="javascript:;">검색어저장 켜기</a><span class="atcmp_bar"></span></em><a class="funoff" href="javascript:;">자동완성 끄기</a></span>,
#  <span class="atcmp_bar"></span>,
#  <span class="atcmp_helper _help_tooltip2">기능을 다시 켤 때는 <em class="ico_search spat">자동완성 펼치기</em>을 클릭하세요</span>,
#  <span class="fl"><a class="_help" href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a><span class="atcmp_bar"></span><a class="report" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=605&amp;categoryNo=18215" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a></span>,
#  <span class="atcmp_bar"></span>,
#  <span><em><a class="hisoff" href="javascript:;">검색어저장 켜기</a><span class="atcmp_bar"></span></em><a class="funoff" href="javascript:;">자동완성 끄기</a></span>,
#  <span class="atcmp_bar"></span>,
#  <span class="atcmp_helper _help_tooltip3">기능을 다시 켤 때는 <em class="ico_search spat">자동완성 펼치기</em>을 클릭하세요</span>,
#  <span class="fl"><a class="_help" href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a><span class="atcmp_bar"></span><a class="report" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=605&amp;categoryNo=18215" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a></span>,
#  <span class="atcmp_bar"></span>,
#  <span><em><a class="hisoff" href="javascript:;">검색어저장 켜기</a><span class="atcmp_bar"></span></em><a class="funoff" href="javascript:;">자동완성 켜기</a></span>,
#  <span class="atcmp_bar"></span>,
#  <span style="display:none">@in_txt@</span>,
#  <span class="star spat">내 검색어 등록</span>,
#  <span class="blind">알림</span>,
#  <span class="blind">알림</span>,
#  <span class="fl"><a class="_delMode" href="javascript:;">기록 삭제</a></span>,
#  <span><a class="_keywordOff" href="javascript:;">검색어저장 끄기</a><span class="atcmp_bar"></span><a class="_acOff" href="javascript:;">자동완성 끄기</a></span>,
#  <span class="atcmp_bar"></span>,
#  <span class="fl"><a class="_delAll" href="javascript:;" title="최근 검색어 기록을 모두 삭제합니다.">기록 전체 삭제</a></span>,
#  <span><a class="_delDone" href="javascript:;">완료</a></span>,
#  <span class="fl"><a class="_delAll" href="javascript:;" title="설정된 내 검색어를 모두 삭제합니다.">기록 전체 삭제</a></span>,
#  <span><a class="_keywordOff" href="javascript:;">검색어저장 끄기</a><span class="atcmp_bar"></span><a class="_acOff" href="javascript:;">자동완성 끄기</a></span>,
#  <span class="atcmp_bar"></span>,
#  <span class="atcmp_helper _help2">기능을 다시 켤 때는 <em class="ico_search spat">자동완성 펼치기</em>을 클릭하세요</span>,
#  <span class="mask"></span>,
#  <span class="ico_alert spat"></span>,
#  <span class="ico_alert spat"></span>,
#  <span class="_passage"></span>,
#  <span class="term"><span class="_term"></span><a class="link _link" href="#" onclick="window.nclick(this,'sug.vote','','',event);" target="_blank">자세히보기</a></span>,
#  <span class="_term"></span>,
#  <span class="veta_bd_t"></span>,
#  <span class="veta_bd_b"></span>,
#  <span class="veta_bd_l"></span>,
#  <span class="veta_bd_r"></span>,
#  <span class="blind">리스트형</span>,
#  <span class="blind">썸네일형</span>,
#  <span class="blind">설정</span>,
#  <span class="blind">이전</span>,
#  <span class="blind">다음</span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">이전</span>,
#  <span class="blind">다음</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">이전</span>,
#  <span class="blind">다음</span>,
#  <span class="blind">다음</span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">이전</span>,
#  <span class="blind">다음</span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">닫기</span>,
#  <span class="dsc">주제별로 분류된 다양한 글 모음</span>,
#  <span class="info"><strong class="new">2,144</strong> 개의 글</span>,
#  <span class="blind">이전</span>,
#  <span class="blind">다음</span>,
#  <span class="thumb_bd"></span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="source"><span class="source_inner">리얼푸드</span></span>,
#  <span class="source_inner">리얼푸드</span>,
#  <span class="thumb_bd"></span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">4일 전</span>,
#  <span class="source"><span class="source_inner">전성기</span></span>,
#  <span class="source_inner">전성기</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">6일 전</span>,
#  <span class="source"><span class="source_inner">리얼푸드 Realfoods</span></span>,
#  <span class="source_inner">리얼푸드 Realfoods</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">제이</span></span>,
#  <span class="source_inner">제이</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">서울대학교병원</span></span>,
#  <span class="source_inner">서울대학교병원</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">04:37</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">5일 전</span>,
#  <span class="source"><span class="source_inner">네이버FARM TV</span></span>,
#  <span class="source_inner">네이버FARM TV</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">05:38</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">5일 전</span>,
#  <span class="source"><span class="source_inner">경상북도TV</span></span>,
#  <span class="source_inner">경상북도TV</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">05:30</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">5일 전</span>,
#  <span class="source"><span class="source_inner">네이버FARM TV</span></span>,
#  <span class="source_inner">네이버FARM TV</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">7개월 전</span>,
#  <span class="source"><span class="source_inner">데일리</span></span>,
#  <span class="source_inner">데일리</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">5일 전</span>,
#  <span class="source"><span class="source_inner">입질의 추억</span></span>,
#  <span class="source_inner">입질의 추억</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">4일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">02:54</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">2주일 전</span>,
#  <span class="source"><span class="source_inner">NBS 한국농업방송 공식채널</span></span>,
#  <span class="source_inner">NBS 한국농업방송 공식채널</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">01:20</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">NBS 한국농업방송 공식채널</span></span>,
#  <span class="source_inner">NBS 한국농업방송 공식채널</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">07:22</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">2주일 전</span>,
#  <span class="source"><span class="source_inner">경상북도TV</span></span>,
#  <span class="source_inner">경상북도TV</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">2일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">잡컴퍼니</span></span>,
#  <span class="source_inner">잡컴퍼니</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">트렌드DA</span></span>,
#  <span class="source_inner">트렌드DA</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">06:56</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">네이버FARM TV</span></span>,
#  <span class="source_inner">네이버FARM TV</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">04:30</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">2주일 전</span>,
#  <span class="source"><span class="source_inner">경상북도TV</span></span>,
#  <span class="source_inner">경상북도TV</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">07:17</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">2주일 전</span>,
#  <span class="source"><span class="source_inner">지나철</span></span>,
#  <span class="source_inner">지나철</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">작은가게오래가게</span></span>,
#  <span class="source_inner">작은가게오래가게</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">3일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1년 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">그린매거진</span></span>,
#  <span class="source_inner">그린매거진</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">3개월 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">03:32</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">2주일 전</span>,
#  <span class="source"><span class="source_inner">NBS 한국농업방송 공식채널</span></span>,
#  <span class="source_inner">NBS 한국농업방송 공식채널</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">05:31</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">4주일 전</span>,
#  <span class="source"><span class="source_inner">서울시50플러스재단</span></span>,
#  <span class="source_inner">서울시50플러스재단</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">03:38</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">2주일 전</span>,
#  <span class="source"><span class="source_inner">네이버FARM TV</span></span>,
#  <span class="source_inner">네이버FARM TV</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">데일리</span></span>,
#  <span class="source_inner">데일리</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">3일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1년 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1개월 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">마이sun원현민</span></span>,
#  <span class="source_inner">마이sun원현민</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">4일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">아리쭈</span></span>,
#  <span class="source_inner">아리쭈</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">이슈잇슈</span></span>,
#  <span class="source_inner">이슈잇슈</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">4일 전</span>,
#  <span class="source"><span class="source_inner">광주광역시농기센터</span></span>,
#  <span class="source_inner">광주광역시농기센터</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">퀘럼</span></span>,
#  <span class="source_inner">퀘럼</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">국민건강보험공단</span></span>,
#  <span class="source_inner">국민건강보험공단</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">6일 전</span>,
#  <span class="source"><span class="source_inner">트리플래닛</span></span>,
#  <span class="source_inner">트리플래닛</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">식약지킴이</span></span>,
#  <span class="source_inner">식약지킴이</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">6개월 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">소믈리에타임즈</span></span>,
#  <span class="source_inner">소믈리에타임즈</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">전원주택라이프</span></span>,
#  <span class="source_inner">전원주택라이프</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1개월 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">야미가든</span></span>,
#  <span class="source_inner">야미가든</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1개월 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">3일 전</span>,
#  <span class="source"><span class="source_inner">여행에미치다</span></span>,
#  <span class="source_inner">여행에미치다</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">한국영농신문</span></span>,
#  <span class="source_inner">한국영농신문</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">4일 전</span>,
#  <span class="source"><span class="source_inner">완주군청</span></span>,
#  <span class="source_inner">완주군청</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">4일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">3일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">3일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">농촌진흥청</span></span>,
#  <span class="source_inner">농촌진흥청</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">미소곡간</span></span>,
#  <span class="source_inner">미소곡간</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">소혹성</span></span>,
#  <span class="source_inner">소혹성</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">5일 전</span>,
#  <span class="source"><span class="source_inner">대한민국 구석구석</span></span>,
#  <span class="source_inner">대한민국 구석구석</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">5일 전</span>,
#  <span class="source"><span class="source_inner">농촌여행 웰촌</span></span>,
#  <span class="source_inner">농촌여행 웰촌</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">강원도</span></span>,
#  <span class="source_inner">강원도</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">브라보마이라이프</span></span>,
#  <span class="source_inner">브라보마이라이프</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">5개월 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">4일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">소혹성</span></span>,
#  <span class="source_inner">소혹성</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">1주일 전</span>,
#  <span class="source"><span class="source_inner">월간 전원속의 내집</span></span>,
#  <span class="source_inner">월간 전원속의 내집</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">5일 전</span>,
#  <span class="source"><span class="source_inner">강원여행</span></span>,
#  <span class="source_inner">강원여행</span>,
#  <span class="thumb_bd"></span>,
#  <span class="date">3일 전</span>,
#  <span class="source"><span class="source_inner">더농부</span></span>,
#  <span class="source_inner">더농부</span>,
#  <span class="blind">NAVER</span>,
#  <span class="blind">이전</span>,
#  <span class="blind">다음</span>,
#  <span class="news">저녁방송 메인뉴스 보기</span>,
#  <span class="news">코로나바이러스감염증19 현황</span>,
#  <span aria-label="최고기온" class="min">28.0°</span>,
#  <span aria-label="최저기온" class="max">20.0°</span>,
#  <span class="location">마곡동</span>,
#  <span class="location">마곡동</span>,
#  <span class="veta_bd_t"></span>,
#  <span class="veta_bd_b"></span>,
#  <span class="veta_bd_l"></span>,
#  <span class="veta_bd_r"></span>,
#  <span class="blind">TOP</span>,
#  <span class="blind">라이트 모드로 보기</span>]

# %%
result_list = naver_bs.find_all('span')
for span in result_list:
    print(span.text)
# Out:
# 뉴스스탠드 바로가기
# 주제별캐스트 바로가기
# 타임스퀘어 바로가기
# 쇼핑캐스트 바로가기
# 로그인 바로가기
# 옆에서 쓰-윽 꺼내보는 재미!
# 다운로드
# NAVER whale
# 네이버
# 쥬니어네이버
# 해피빈
# 검색
#
#
# 입력도구
# 자동완성/최근검색어 펼치기
#
#
# 시간대와 관심사에 맞춘 컨텍스트 자동완성
# 도움말 보기
#
# 시간대와 관심사에 맞춘 컨텍스트 자동완성
# 도움말 보기
#
# ON선택됨
# OFF
#
# 선택됨
# 도움말신고
#
# 검색어저장 켜기자동완성 끄기
#
# 기능을 다시 켤 때는 자동완성 펼치기을 클릭하세요
# 도움말신고
#
# 검색어저장 켜기자동완성 끄기
#
# 기능을 다시 켤 때는 자동완성 펼치기을 클릭하세요
# 도움말신고
#
# 검색어저장 켜기자동완성 끄기
#
# 기능을 다시 켤 때는 자동완성 펼치기을 클릭하세요
# 도움말신고
#
# 검색어저장 켜기자동완성 켜기
#
# @in_txt@
# 내 검색어 등록
# 알림
# 알림
# 기록 삭제
# 검색어저장 끄기자동완성 끄기
#
# 기록 전체 삭제
# 완료
# 기록 전체 삭제
# 검색어저장 끄기자동완성 끄기
#
# 기능을 다시 켤 때는 자동완성 펼치기을 클릭하세요
#
#
#
#
# 자세히보기
#
#
#
#
#
# 리스트형
# 썸네일형
# 설정
# 이전
# 다음
# 닫기
# 닫기
# 이전
# 다음
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 닫기
# 닫기
# 이전
# 다음
# 다음
# 닫기
# 닫기
# 이전
# 다음
# 닫기
# 닫기
# 주제별로 분류된 다양한 글 모음
# 2,144 개의 글
# 이전
# 다음
#
# 더농부
# 더농부
#
# 리얼푸드
# 리얼푸드
#
# 더농부
# 더농부
#
# 더농부
# 더농부
#
# 4일 전
# 전성기
# 전성기
#
# 6일 전
# 리얼푸드 Realfoods
# 리얼푸드 Realfoods
#
# 1주일 전
# 제이
# 제이
#
# 1주일 전
# 서울대학교병원
# 서울대학교병원
#
#
# 재생
# 재생시간04:37
# 재생시간
# 5일 전
# 네이버FARM TV
# 네이버FARM TV
#
#
# 재생
# 재생시간05:38
# 재생시간
# 5일 전
# 경상북도TV
# 경상북도TV
#
#
# 재생
# 재생시간05:30
# 재생시간
# 5일 전
# 네이버FARM TV
# 네이버FARM TV
#
# 7개월 전
# 데일리
# 데일리
#
# 1주일 전
# 더농부
# 더농부
#
# 5일 전
# 입질의 추억
# 입질의 추억
#
# 4일 전
# 더농부
# 더농부
#
#
# 재생
# 재생시간02:54
# 재생시간
# 2주일 전
# NBS 한국농업방송 공식채널
# NBS 한국농업방송 공식채널
#
#
# 재생
# 재생시간01:20
# 재생시간
# 1주일 전
# NBS 한국농업방송 공식채널
# NBS 한국농업방송 공식채널
#
#
# 재생
# 재생시간07:22
# 재생시간
# 2주일 전
# 경상북도TV
# 경상북도TV
#
# 2일 전
# 더농부
# 더농부
#
# 1주일 전
# 더농부
# 더농부
#
# 1주일 전
# 잡컴퍼니
# 잡컴퍼니
#
# 1주일 전
# 더농부
# 더농부
#
# 1주일 전
# 트렌드DA
# 트렌드DA
#
#
# 재생
# 재생시간06:56
# 재생시간
# 1주일 전
# 네이버FARM TV
# 네이버FARM TV
#
#
# 재생
# 재생시간04:30
# 재생시간
# 2주일 전
# 경상북도TV
# 경상북도TV
#
#
# 재생
# 재생시간07:17
# 재생시간
# 2주일 전
# 지나철
# 지나철
#
# 1주일 전
# 작은가게오래가게
# 작은가게오래가게
#
# 3일 전
# 더농부
# 더농부
#
# 1년 전
# 더농부
# 더농부
#
# 1주일 전
# 그린매거진
# 그린매거진
#
# 3개월 전
# 더농부
# 더농부
#
#
# 재생
# 재생시간03:32
# 재생시간
# 2주일 전
# NBS 한국농업방송 공식채널
# NBS 한국농업방송 공식채널
#
#
# 재생
# 재생시간05:31
# 재생시간
# 4주일 전
# 서울시50플러스재단
# 서울시50플러스재단
#
#
# 재생
# 재생시간03:38
# 재생시간
# 2주일 전
# 네이버FARM TV
# 네이버FARM TV
#
# 1주일 전
# 데일리
# 데일리
#
# 3일 전
# 더농부
# 더농부
#
# 1년 전
# 더농부
# 더농부
#
# 1개월 전
# 더농부
# 더농부
#
# 1주일 전
# 마이sun원현민
# 마이sun원현민
#
# 4일 전
# 더농부
# 더농부
#
# 1주일 전
# 아리쭈
# 아리쭈
#
# 1주일 전
# 이슈잇슈
# 이슈잇슈
#
# 4일 전
# 광주광역시농기센터
# 광주광역시농기센터
#
# 1주일 전
# 퀘럼
# 퀘럼
#
# 1주일 전
# 국민건강보험공단
# 국민건강보험공단
#
# 6일 전
# 트리플래닛
# 트리플래닛
#
# 1주일 전
# 식약지킴이
# 식약지킴이
#
# 6개월 전
# 더농부
# 더농부
#
# 1주일 전
# 소믈리에타임즈
# 소믈리에타임즈
#
# 1주일 전
# 전원주택라이프
# 전원주택라이프
#
# 1개월 전
# 더농부
# 더농부
#
# 1주일 전
# 야미가든
# 야미가든
#
# 1개월 전
# 더농부
# 더농부
#
# 3일 전
# 여행에미치다
# 여행에미치다
#
# 1주일 전
# 한국영농신문
# 한국영농신문
#
# 1주일 전
# 더농부
# 더농부
#
# 4일 전
# 완주군청
# 완주군청
#
# 4일 전
# 더농부
# 더농부
#
# 3일 전
# 더농부
# 더농부
#
# 3일 전
# 더농부
# 더농부
#
# 1주일 전
# 농촌진흥청
# 농촌진흥청
#
# 1주일 전
# 미소곡간
# 미소곡간
#
# 1주일 전
# 소혹성
# 소혹성
#
# 5일 전
# 대한민국 구석구석
# 대한민국 구석구석
#
# 5일 전
# 농촌여행 웰촌
# 농촌여행 웰촌
#
# 1주일 전
# 강원도
# 강원도
#
# 1주일 전
# 브라보마이라이프
# 브라보마이라이프
#
# 5개월 전
# 더농부
# 더농부
#
# 1주일 전
# 더농부
# 더농부
#
# 4일 전
# 더농부
# 더농부
#
# 1주일 전
# 소혹성
# 소혹성
#
# 1주일 전
# 월간 전원속의 내집
# 월간 전원속의 내집
#
# 5일 전
# 강원여행
# 강원여행
#
# 3일 전
# 더농부
# 더농부
# NAVER
# 이전
# 다음
# 저녁방송 메인뉴스 보기
# 코로나바이러스감염증19 현황
# 28.0°
# 20.0°
# 마곡동
# 마곡동
#
#
#
#
# TOP
# 라이트 모드로 보기

# %% [markdown]
# ## 3.3 재무 데이터 구해 오기

# %%
import pandas as pd

fs_url = 'http://comp.fnguide.com/SVO2/asp/SVD_Finance.asp?pGB=1&gicode=A005930&cID=&MenuYn=Y&ReportGB=&NewMenuID=103&stkGb=701'
fs_page = requests.get(fs_url)
fs_tables = pd.read_html(fs_page.text) # 연간, 분기 2개씩 나옴. 포괄손익, 재무제표, 현금흐름 = 6개

# %%
fs_tables[0]
# Out:
#                               IFRS(연결)    2017/12    2018/12    2019/12  \
# 0                                  매출액  2395754.0  2437714.0  2304009.0
# 1                                 매출원가  1292907.0  1323944.0  1472395.0
# 2                                매출총이익  1102847.0  1113770.0   831613.0
# 3                판매비와관리비계산에 참여한 계정 펼치기   566397.0   524903.0   553928.0
# 4                                 영업이익   536450.0   588867.0   277685.0
# 5                           영업이익(발표기준)   536450.0   588867.0   277685.0
# 6                   금융수익계산에 참여한 계정 펼치기    97374.0    99993.0   101616.0
# 7                   금융원가계산에 참여한 계정 펼치기    89789.0    86089.0    82749.0
# 8                   기타수익계산에 참여한 계정 펼치기    30107.0    14850.0    17787.0
# 9                   기타비용계산에 참여한 계정 펼치기    14196.0    11420.0    14147.0
# 10  종속기업,공동지배기업및관계기업관련손익계산에 참여한 계정 펼치기     2014.0     5398.0     4130.0
# 11                            세전계속사업이익   561960.0   611600.0   304322.0
# 12                               법인세비용   140092.0   168151.0    86933.0
# 13                              계속영업이익   421867.0   443449.0   217389.0
# 14                              중단영업이익        NaN        NaN        NaN
# 15                               당기순이익   421867.0   443449.0   217389.0
# 16                             지배주주순이익   413446.0   438909.0   215051.0
# 17                            비지배주주순이익     8422.0     4540.0     2338.0
#
#      2020/03      전년동기 전년동기(%)
# 0   553252.0  523855.0     5.6
# 1   348067.0  327465.0     6.3
# 2   205185.0  196391.0     4.5
# 3   140711.0  134058.0     5.0
# 4    64473.0   62333.0     3.4
# 5    64473.0   62333.0     3.4
# 6    37914.0   19165.0    97.8
# 7    34940.0   13792.0   153.3
# 8     3155.0    3218.0    -2.0
# 9     3641.0    2571.0    41.6
# 10     606.0     777.0   -21.9
# 11   67569.0   69130.0    -2.3
# 12   18719.0   18694.0     0.1
# 13   48849.0   50436.0    -3.1
# 14       NaN       NaN     NaN
# 15   48849.0   50436.0    -3.1
# 16   48896.0   51075.0    -4.3
# 17     -47.0    -639.0    적자지속

# %%
# 포괄손익계산서
temp_df = fs_tables[0]
temp_df = temp_df.set_index('IFRS(연결)')
temp_df = temp_df[['2017/12', '2018/12', '2019/12', '2020/03']]
temp_df
# Out:
#                                       2017/12    2018/12    2019/12   2020/03
# IFRS(연결)
# 매출액                                 2395754.0  2437714.0  2304009.0  553252.0
# 매출원가                                1292907.0  1323944.0  1472395.0  348067.0
# 매출총이익                               1102847.0  1113770.0   831613.0  205185.0
# 판매비와관리비계산에 참여한 계정 펼치기                566397.0   524903.0   553928.0  140711.0
# 영업이익                                 536450.0   588867.0   277685.0   64473.0
# 영업이익(발표기준)                           536450.0   588867.0   277685.0   64473.0
# 금융수익계산에 참여한 계정 펼치기                    97374.0    99993.0   101616.0   37914.0
# 금융원가계산에 참여한 계정 펼치기                    89789.0    86089.0    82749.0   34940.0
# 기타수익계산에 참여한 계정 펼치기                    30107.0    14850.0    17787.0    3155.0
# 기타비용계산에 참여한 계정 펼치기                    14196.0    11420.0    14147.0    3641.0
# 종속기업,공동지배기업및관계기업관련손익계산에 참여한 계정 펼치기     2014.0     5398.0     4130.0     606.0
# 세전계속사업이익                             561960.0   611600.0   304322.0   67569.0
# 법인세비용                                140092.0   168151.0    86933.0   18719.0
# 계속영업이익                               421867.0   443449.0   217389.0   48849.0
# 중단영업이익                                    NaN        NaN        NaN       NaN
# 당기순이익                                421867.0   443449.0   217389.0   48849.0
# 지배주주순이익                              413446.0   438909.0   215051.0   48896.0
# 비지배주주순이익                               8422.0     4540.0     2338.0     -47.0

# %%
# 사용할 행들만 선택
temp_df = temp_df.loc[['매출액', '영업이익', '당기순이익']]
temp_df
# Out:
#             2017/12    2018/12    2019/12   2020/03
# IFRS(연결)
# 매출액       2395754.0  2437714.0  2304009.0  553252.0
# 영업이익       536450.0   588867.0   277685.0   64473.0
# 당기순이익      421867.0   443449.0   217389.0   48849.0

# %%
# 재무상태표와 현금흐름표
temp_df2 = fs_tables[2]
temp_df2 = temp_df2.set_index('IFRS(연결)')
temp_df2 = temp_df2.loc[['자산', '부채', '자본']]

temp_df3 = fs_tables[4]
temp_df3 = temp_df3.set_index('IFRS(연결)')
temp_df3 = temp_df3.loc[['영업활동으로인한현금흐름']]

# %%
fs_df = pd.concat([temp_df, temp_df2, temp_df3]) # 행을 위아래로 붙임
fs_df
# Out:
#                 2017/12    2018/12    2019/12    2020/03
# IFRS(연결)
# 매출액           2395754.0  2437714.0  2304009.0   553252.0
# 영업이익           536450.0   588867.0   277685.0    64473.0
# 당기순이익          421867.0   443449.0   217389.0    48849.0
# 자산            3017521.0  3393572.0  3525645.0  3574575.0
# 부채             872607.0   916041.0   896841.0   910698.0
# 자본            2144914.0  2477532.0  2628804.0  2663877.0
# 영업활동으로인한현금흐름   621620.0   670319.0   453829.0   118299.0

# %%
# 회사 코드가 들어가면 데이터프레임 생성하게 만듬
def make_fs_dataframe(firm_code):
    fs_url = 'https://comp.fnguide.com/SVO2/asp/SVD_Finance.asp?pGB=1&cID=&MenuYn=Y&ReportGB=D&NewMenuID=103&stkGb=701&gicode=' + firm_code
    fs_page = requests.get(fs_url)
    fs_tables = pd.read_html(fs_page.text)
    
    temp_df = fs_tables[0]
    temp_df = temp_df.set_index(temp_df.columns[0])
    temp_df = temp_df[temp_df.columns[:4]]
    temp_df = temp_df.loc[['매출액', '영업이익', '당기순이익']]

    temp_df2 = fs_tables[2]
    temp_df2 = temp_df2.set_index(temp_df2.columns[0])
    temp_df2 = temp_df2.loc[['자산', '부채', '자본']]

    temp_df3 = fs_tables[4]
    temp_df3 = temp_df3.set_index(temp_df3.columns[0])
    temp_df3 = temp_df3.loc[['영업활동으로인한현금흐름']]

    fs_df = pd.concat([temp_df, temp_df2, temp_df3])
    
    return fs_df

# %%
make_fs_dataframe('A005380') # 현대차 제무재표
# Out:
#                 2017/12    2018/12    2019/12    2020/03
# IFRS(연결)
# 매출액            963761.0   968126.0  1057464.0   253194.0
# 영업이익            45747.0    24222.0    36055.0     8638.0
# 당기순이익           45464.0    16450.0    31856.0     5527.0
# 자산            1781995.0  1806558.0  1945122.0  1988508.0
# 부채            1034421.0  1067597.0  1181465.0  1229242.0
# 자본             747574.0   738960.0   763658.0   759266.0
# 영업활동으로인한현금흐름    39224.0    37643.0     4198.0     8220.0

# %%
# 2000여 개의 회사코드를 인덱싱하여 같이 관리하는게 효율적이다.
# 형태 바꾸기

code = 'A005930'
fs_df = make_fs_dataframe(code)
temp_df = pd.DataFrame({code : fs_df['2017/12']})
temp_df = temp_df.T # 데이터프레임의 행과 열을 바꾸는 명령어
temp_df.columns = [['2017/12']*len(fs_df), temp_df.columns] # 이중 칼럼에서 위에 갈 칼럼을 앞에 넣고 미으로 갈 칼럼을 뒤에 넣는다.
temp_df
# Out:
#             2017/12                                                      \
# IFRS(연결)        매출액      영업이익     당기순이익         자산        부채         자본
# A005930   2395754.0  536450.0  421867.0  3017521.0  872607.0  2144914.0
#
#
# IFRS(연결) 영업활동으로인한현금흐름
# A005930      621620.0

# %%
def change_df(firm_code, dataframe):
    for num, col in enumerate(dataframe.columns):
        temp_df = pd.DataFrame({code : dataframe[col]})
        temp_df = temp_df.T
        temp_df.columns = [[col]*len(dataframe), temp_df.columns]
        if num == 0:
            total_df = temp_df
        else:
             total_df = pd.merge(total_df, temp_df, how='outer', left_index=True, right_index=True)
    return total_df

# %%
# 5개 회사 재무제포 데이터를 합쳐보기
firmcode_list = ['A005930', 'A005380', 'A035420', 'A003550', 'A034730']

for num, code in enumerate(firmcode_list):
    fs_df = make_fs_dataframe(code)
    fs_df_changed = change_df(code, fs_df)
    if num == 0:
        total_fs = fs_df_changed
    else:
        total_fs = pd.concat([total_fs, fs_df_changed])
total_fs

# 참고로 A005390 같은 기업의 연도는 2017/06 결산 연도가 다른건 데이터가 안나올 수 있음
# Out:
#             2017/12                                                       \
# IFRS(연결)        매출액      영업이익     당기순이익         자산         부채         자본
# A005930   2395754.0  536450.0  421867.0  3017521.0   872607.0  2144914.0
# A005380    963761.0   45747.0   45464.0  1781995.0  1034421.0   747574.0
# A035420     46785.0   11792.0    7701.0    80193.0    27141.0    53052.0
# A003550    118411.0   21858.0   24356.0   216477.0    54682.0   161795.0
# A034730    906128.0   57450.0   50665.0  1097835.0   640270.0   457564.0
#
#                          2018/12                      ...    2019/12  \
# IFRS(연결) 영업활동으로인한현금흐름        매출액      영업이익     당기순이익  ...         부채
# A005930      621620.0  2437714.0  588867.0  443449.0  ...   896841.0
# A005380       39224.0   968126.0   24222.0   16450.0  ...  1181465.0
# A035420        9400.0    55869.0    9425.0    6279.0  ...    57956.0
# A003550       10584.0    77434.0   18213.0   18829.0  ...    34136.0
# A034730       69301.0  1001616.0   46838.0   61511.0  ...   798380.0
#
#                                    2020/03                               \
# IFRS(연결)         자본 영업활동으로인한현금흐름       매출액     영업이익    당기순이익         자산
# A005930   2628804.0     453829.0  553252.0  64473.0  48849.0  3574575.0
# A005380    763658.0       4198.0  253194.0   8638.0   5527.0  1988508.0
# A035420     65039.0      13568.0   17321.0   2215.0   1349.0   137660.0
# A003550    190210.0       8187.0   15854.0   6077.0   5921.0   226349.0
# A034730    521826.0      79788.0  237261.0  -9227.0  -8324.0  1351392.0
#
#
# IFRS(연결)         부채         자본 영업활동으로인한현금흐름
# A005930    910698.0  2663877.0     118299.0
# A005380   1229242.0   759266.0       8220.0
# A035420     63108.0    74552.0       2779.0
# A003550     33548.0   192801.0       2507.0
# A034730    837787.0   513605.0       9948.0
#
# [5 rows x 28 columns]

# %%
# 재무비율 탭에 있느 데이터를 가져와서 똑같은 방법으로 정리해보자

def make_fr_dataframe(firm_code):
# firm_code = 'A005930'
    fr_url = 'https://comp.fnguide.com/SVO2/asp/SVD_FinanceRatio.asp?pGB=1&cID=&MenuYn=Y&ReportGB=D&NewMenuID=104&stkGb=701&gicode=' + firm_code
    fr_page = requests.get(fr_url)
    fr_tables = pd.read_html(fr_page.text)

    temp_df = fr_tables[0]
    temp_df = temp_df.set_index(temp_df.columns[0])

# (현재 책)책 내용과 현재 url에 있는 구성이 다름
#     temp_df = temp_df.loc[['유동비율(유동자산 / 유동부채) * 100 유동비율계산에 참여한 계정 펼치기',
#                            '부채비율(총부채 / 총자본) * 100 부채비율계산에 참여한 계정 펼치기',
#                            '영업이익률(영업이익 / 영업수익) * 100 영업이익률계산에 참여한 계정 펼치기',
#                            'ROA(당기순이익(연율화) / 총자산(평균)) * 100 ROA계산에 참여한 계정 펼치기',
#                            'ROIC(세후영업이익(연율화)/영업투하자본(평균))*100 ROIC계산에 참여한 계정 펼치기']]

    temp_df = temp_df.loc[['유동비율계산에 참여한 계정 펼치기',
                           '부채비율계산에 참여한 계정 펼치기',
                           '영업이익률계산에 참여한 계정 펼치기',
                           'ROA계산에 참여한 계정 펼치기',
                           'ROIC계산에 참여한 계정 펼치기']]

    temp_df.index = ['유동비율', '부채비율', '영업이익률', 'ROA', 'ROIC']
    return temp_df
temp_df
# Out:
#             2017/12                                                      \
# IFRS(연결)        매출액      영업이익     당기순이익         자산        부채         자본
# A005930   2395754.0  536450.0  421867.0  3017521.0  872607.0  2144914.0
#
#
# IFRS(연결) 영업활동으로인한현금흐름
# A005930      621620.0

# %%
# 5개 회사 재무비율 데이터를 합쳐보기
firmcode_list = ['A005930', 'A005380', 'A035420', 'A003550', 'A034730']

for num, code in enumerate(firmcode_list):
    fr_df = make_fr_dataframe(code)
    fr_df_changed = change_df(code, fr_df)
    if num == 0:
        total_fr = fr_df_changed
    else:
        total_fr = pd.concat([total_fr, fr_df_changed])
total_fr
# Out:
#         2016/12                           2017/12                            \
#            유동비율   부채비율 영업이익률   ROA   ROIC    유동비율   부채비율 영업이익률   ROA   ROIC
# A005930   258.5   35.9  14.5   9.0   20.3   218.8   40.7  22.4  15.0   33.2
# A005380   109.1  147.2   5.6   3.3    4.4   112.2  138.4   4.8   2.6    4.8
# A035420   232.8   54.3  27.4  14.1  199.2   207.8   51.2  25.2  10.7  144.9
# A003550   130.7   37.1  13.7   5.8   39.5   136.1   33.8  18.5  11.8   87.7
# A034730   113.0  143.5   6.4   2.8    7.8   112.2  139.9   6.3   4.8    8.4
#
#          ... 2019/12                         2020/03
#          ...    유동비율   부채비율 영업이익률  ROA  ROIC    유동비율   부채비율 영업이익률   ROA   ROIC
# A005930  ...   284.4   34.1  12.1  6.3  13.2   288.3   34.2  11.7   5.5   12.0
# A005380  ...    86.1  154.7   3.4  1.7   2.6    85.2  161.9   3.4   1.1    2.4
# A035420  ...   149.6   89.1  10.8  3.6  36.6   159.5   84.7  12.8   4.1   42.5
# A003550  ...   175.5   18.0  15.6  4.9  41.8   173.4   17.4  38.3  10.5  149.0
# A034730  ...   112.6  153.0   4.0  1.3   4.3   105.3  163.1  -3.9  -2.5   -4.4
#
# [5 rows x 25 columns]

# %%
# 투자지표 탭에 있는 데이터 가져오기

def make_invest_dataframe(firm_code):
    invest_url = 'https://comp.fnguide.com/SVO2/asp/SVD_Invest.asp?pGB=1&cID=&MenuYn=Y&ReportGB=D&NewMenuID=105&stkGb=701&gicode=' + firm_code
    invest_page = requests.get(invest_url)
    invest_tables = pd.read_html(invest_page.text)
    temp_df = invest_tables[1]
    
    temp_df = temp_df.set_index(temp_df.columns[0])
    temp_df = temp_df.loc[['PER계산에 참여한 계정 펼치기',
                           'PCR계산에 참여한 계정 펼치기',
                           'PSR계산에 참여한 계정 펼치기',
                           'PBR계산에 참여한 계정 펼치기',
                           '총현금흐름']]
    temp_df.index = ['PER', 'PCR', 'PSR', 'PBR', '총현금흐름']
    return temp_df

# %%
# 5개 회사 투자지표 데이터를 합쳐보기
firmcode_list = ['A005930', 'A005380', 'A035420', 'A003550', 'A034730']

for num, code in enumerate(firmcode_list):
    invest_df = make_invest_dataframe(code)
    invest_df_changed = change_df(code, invest_df)
    if num == 0:
        total_invest = invest_df_changed
    else:
        total_invest = pd.concat([total_invest, invest_df_changed])
total_invest
# Out:
#         2016/12                            2017/12                             \
#             PER    PCR   PSR   PBR   총현금흐름     PER    PCR   PSR   PBR   총현금흐름
# A005930   13.18   6.85  1.46  1.48  423491    9.40   6.12  1.62  1.76  623891
# A005380    7.71   4.76  0.45  0.61   74241   11.04   5.89  0.46  0.63   82152
# A035420   34.14  28.04  6.36  5.17    9136   37.16  29.33  6.14  4.84    9682
# A003550    9.82   7.69  1.09  0.76   14278    6.68   6.03  1.35  1.00   21812
# A034730   21.26   2.72  0.20  1.16   88583   11.97   2.74  0.22  1.38   96487
#
#          ... 2019/12                            2020/03                  \
#          ...     PER    PCR   PSR   PBR   총현금흐름     PER  PCR  PSR   PBR
# A005930  ...   17.63   7.42  1.65  1.49  494337     NaN  NaN  NaN  1.25
# A005380  ...   11.20   4.90  0.32  0.47   65904     NaN  NaN  NaN  0.35
# A035420  ...   52.72  28.43  4.66  4.27    8261     NaN  NaN  NaN  3.49
# A003550  ...   12.02  10.33  1.97  0.69    9937     NaN  NaN  NaN  0.54
# A034730  ...   25.91   2.26  0.19  1.00   99334     NaN  NaN  NaN  0.63
#
#
#           총현금흐름
# A005930  120668
# A005380   16682
# A035420    1177
# A003550    6269
# A034730   12325
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 3.4 전 종목 코드 구해오기

# %%
path = r'C:\\work\\hun\\python_quant\\data\\data.xls' # KRX 에서 전체 종목 다운로드
code_data = pd.read_excel(path)
code_data = code_data[['종목코드', '기업명']]
code_data
# Out:
#         종목코드     기업명
# 0      60310      3S
# 1      95570  AJ네트웍스
# 2       6840   AK홀딩스
# 3      54620  APS홀딩스
# 4     265520   AP시스템
# ...      ...     ...
# 2351  189980  흥국에프엔비
# 2352     540    흥국화재
# 2353    3280    흥아해운
# 2354   37440      희림
# 2355  238490      힘스
#
# [2356 rows x 2 columns]

# %%
# 종목코드 칼럼 개선
def make_code(x):
    x = str(x)
    return 'A'+'0'*(6-len(x))+x

code_data['종목코드'] = code_data['종목코드'].apply(make_code)
code_data # 실행할때마다 A 가 앞에 붙음..
# Out:
#          종목코드     기업명
# 0     A060310      3S
# 1     A095570  AJ네트웍스
# 2     A006840   AK홀딩스
# 3     A054620  APS홀딩스
# 4     A265520   AP시스템
# ...       ...     ...
# 2351  A189980  흥국에프엔비
# 2352  A000540    흥국화재
# 2353  A003280    흥아해운
# 2354  A037440      희림
# 2355  A238490      힘스
#
# [2356 rows x 2 columns]

# %% [markdown]
# ## 3.5 전 종목 재무데이터 가져오기

# %%
# 모든 종목에 대한 재무데이터 가져오기

import time

for num, code in enumerate(code_data['종목코드']):
    try:
        print(num, code)
        time.sleep(1)
        try:
            fs_df = make_fs_dataframe(code)
        except requests.exceptions.Timeout:
            time.sleep(60)
            fs_df = make_fs_dataframe(code)
        fs_df_changed = change_df(code, fs_df)
        if num == 0:
            total_fs = fs_df_changed
        else:
            total_fs = pd.concat([total_fs, fs_df_changed])
    except ValueError:
        continue
    except KeyError:
        continue

# total_fs # 결산일이 12월, 3월로 다른 기업들이 있어서 데이터가 NaN으로 표기될 수 있음
total_fs[['2017/12', '2018/12', '2019/12', '2020/03']] # 날짜 데이터만 가져옴
# Out:
# 0 A060310
# 1 A095570
# 2 A006840
# 3 A054620
# 4 A265520
# 5 A211270
# 6 A027410
# 7 A282330
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-8023dadcd002> in <module>
#       6     try:
#       7         print(num, code)
# ----> 8         time.sleep(1)
#       9         try:
#      10             fs_df = make_fs_dataframe(code)
#
# KeyboardInterrupt:

# %%
# 재무데이터를 엑셀로 저장
total_fs.to_excel(r'재무데이터.xlsx')

# %%
# 모든 종목 재무비율 데이터 합치고 엑셀에 저장

for num, code in enumerate(code_data['종목코드']):
    try:
        print(num, code)
        time.sleep(1)
        try:
            fr_df = make_fr_dataframe(code)
        except requests.exceptions.Timeout:
            time.sleep(60)
            fr_df = make_fr_dataframe(code)
        fr_df_changed = change_df(code, fr_df)
        if num == 0 :
            total_fr = fr_df_changed
        else:
            total_fr = pd.concat([total_fr, fr_df_changed])
    except ValueError:
        continue
    except KeyError:
        continue
        
total_fr.to_excel(r'재무비율데이터.xlsx')
# Out:
# 0 A060310
# 1 A095570
# 2 A006840
# 3 A054620
# 4 A265520
# 5 A211270
# 6 A027410
# 7 A282330
# 8 A138930
# 9 A001460
# 10 A001040
# 11 A079160
# 12 A035760
# 13 A000120
# 14 A011150
# 15 A097950
# 16 A051500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-7b38296047eb> in <module>
#       4     try:
#       5         print(num, code)
# ----> 6         time.sleep(1)
#       7         try:
#       8             fr_df = make_fr_dataframe(code)
#
# KeyboardInterrupt:

# %%
# 모든 종목 투자지표 데이터 합치고 엑셀에 저장

for num, code in enumerate(code_data['종목코드'][313:]):
    try:
        print(num, code)
        time.sleep(1)
        try:
            invest_df = make_invest_dataframe(code)
        except requests.exceptions.Timeout:
            time.sleep(60)
            invest_df = make_invest_dataframe(code)
        invest_df_changed = change_df(code, invest_df)
        if num == 0 :
            total_invest = invest_df_changed
        else:
            total_invest = pd.concat([total_invest, invest_df_changed])
    except ValueError:
        continue
    except KeyError:
        continue
        
total_invest.to_excel(r'투자지표데이터.xlsx')
# Out:
# 0 A086220
# 1 A033640
# 2 A087730
# 3 A005720
# 4 A002350
# 5 A089140
# 6 A065170
# 7 A139670
# 8 A003580
# 9 A137940
# 10 A041140
# 11 A217270
# 12 A225570
# 13 A251270
# 14 A104620
# 15 A090350
# 16 A000320
# 17 A194700
# 18 A285490
# 19 A229500
# 20 A006280
# 21 A144510
# 22 A031390
# 23 A142280
# 24 A005250
# 25 A065560
# 26 A004370
# 27 A072710
# 28 A054050
# 29 A040160
# 30 A069140
# 31 A126870
# 32 A060260
# 33 A012340
# 34 A270870
# 35 A222040
# 36 A144960
# 37 A900100
# 38 A085670
# 39 A119860
# 40 A064260
# 41 A093640
# 42 A039560
# 43 A058730
# 44 A023590
# 45 A032190
# 46 A068240
# 47 A086080
# 48 A271850
# 49 A019680
# 50 A006370
# 51 A008060
# 52 A178600
# 53 A000490
# 54 A020400
# 55 A008830
# 56 A048470
# 57 A008110
# 58 A004780
# 1862 A143210
# 1863 A900270
# 1864 A000720
# 1865 A267270
# 1866 A170030
# 1867 A005440
# 1868 A086280
# 1869 A064350
# 1870 A079430
# 1871 A012330
# 1872 A010620
# 1873 A048410
# 1874 A069960
# 1875 A004560
# 1876 A016790
# 1877 A011200
# 1878 A004310
# 1879 A126560
# 1880 A017800
# 1881 A011210
# 1882 A267260
# 1883 A005380
# 1884 A026180
# 1885 A004020
# 1886 A011760
# 1887 A009540
# 1888 A267250
# 1889 A001500
# 1890 A227840
# 1891 A039010
# 1892 A001450
# 1893 A057050
# 1894 A204990
# 1895 A092300
# 1896 A053660
# 1897 A011080
# 1898 A093240
# 1899 A003010
# 1900 A111110
# 1901 A008770
# 1902 A060560
# 1903 A064240
# 1904 A039610
# 1905 A002460
# 1906 A013520
# 1907 A241590
# 1908 A006060
# 1909 A010690
# 1910 A126640
# 1911 A086250
# 1912 A204630
# 1913 A133820
# 1914 A061250
# 1915 A134780
# 1916 A010660
# 1917 A000850
# 1918 A123260
# 1919 A016580
# 1920 A032560
# 1921 A004800
# 1922 A094280
# 1923 A097870
# 1924 A298040
# 1925 A298050
# 1926 A298020
# 1927 A298000
# 1928 A093370
# 1929 A050090
# 1930 A081660
# 1931 A290270
# 1932 A005870
# 1933 A284420
# 1934 A205470
# 1935 A115160
# 1936 A028080
# 1937 A200670
# 1938 A212310
# 1939 A079980
# 1940 A065510
# 1941 A005010
# 1942 A243070
# 1943 A084110
# 1944 A145020
# 1945 A069260
# 1946 A024060
# 1947 A010240
# 1948 A189980
# 1949 A000540
# 1950 A003280
# 1951 A037440
# 1952 A238490

# %% [markdown]
# ## 3.6 가격 데이터 가져오기

# %%
import requests
import bs4
import pandas as pd
import time

price_url = 'https://fchart.stock.naver.com/sise.nhn?symbol=005935&timeframe=day&count=1500&requestType=0'
price_data = requests.get(price_url)

price_data_bs = bs4.BeautifulSoup(price_data.text, 'lxml')
item_list = price_data_bs.find_all('item')
temp = item_list[0]['data']
temp.split('|') # 순서대로 날짜, 시가, 고가, 저가, 종가, 거래량

date_list = []
price_list = []
for item in item_list:
    temp_data = item['data']
    datas = temp_data.split('|')
    date_list.append(datas[0])
    price_list.append(datas[4])

price_df = pd.DataFrame({'종가' : price_list}, index=date_list) # 인덱스가 날짜, 칼럼이 종가
price_df
# Out:
#              종가
# 20140619  20720
# 20140620  20780
# 20140623  21180
# 20140624  21600
# 20140625  21420
# ...         ...
# 20200720  46950
# 20200721  47700
# 20200722  47250
# 20200723  47050
# 20200724  47150
#
# [1500 rows x 1 columns]

# %%
# 가격을 naver차트로부터 가져와 dataframe 만드는 함수
# 칼럼명을 종가 -> 회사코드로 바꿈
def make_price_dataframe(code, timeframe, count):
    url = 'https://fchart.stock.naver.com/sise.nhn?requestType=0'
    price_url = url + '&symbol='+ code + '&timeframe=' + timeframe + '&count=' + count
    price_data = requests.get(price_url)
    price_data_bs = bs4.BeautifulSoup(price_data.text, 'lxml')
    item_list = price_data_bs.find_all('item')
    
    date_list = []
    price_list = []
    for item in item_list:
        temp_data = item['data']
        datas = temp_data.split('|')
        date_list.append(datas[0])
        price_list.append(datas[4])

    price_df = pd.DataFrame({code:price_list}, index=date_list)
    
    return price_df

# %%
make_price_dataframe('005380', 'day', '1500')
# Out:
#           005380
# 20140619  223500
# 20140620  218000
# 20140623  219500
# 20140624  224500
# 20140625  228500
# ...          ...
# 20200720  121500
# 20200721  121500
# 20200722  118500
# 20200723  124500
# 20200724  122500
#
# [1500 rows x 1 columns]

# %%
# 5개 회사 날짜별로 종가 merge하기 (옆으로)
firmcode_list = ['005930', '005380', '035420', '003550', '034730']

for num, code in enumerate(firmcode_list):
    price_df = make_price_dataframe(code, 'day', '1500')
    if num == 0:
        total_price = price_df
    else:
        total_price = pd.merge(total_price, price_df, how='outer', right_index=True, left_index=True)

total_price
# Out:
#          005930  005380  035420 003550  034730
# 20140619  26460  223500  155621  63200  170500
# 20140620  26020  218000  157624  61800  172500
# 20140623  26440  219500  165435  61700  172500
# 20140624  26900  224500  165234  64300  171500
# 20140625  26400  228500  164634  63200  166000
# ...         ...     ...     ...    ...     ...
# 20200720  54200  121500  263000  71800  231000
# 20200721  55300  121500  270000  72200  233500
# 20200722  54700  118500  270000  73200  235500
# 20200723  54100  124500  284000  72600  230000
# 20200724  54200  122500  281000  72100  224500
#
# [1500 rows x 5 columns]

# %%
# 거래소에서 가져온 회사코드 데이터의 'A'는 빼고 데이터프레임 만듬
path = r'C:\\work\\hun\\python_quant\\data\\data.xls'
code_data = pd.read_excel(path)
code_data = code_data[['종목코드', '기업명']]

def make_code2(x):
    x = str(x)
    return '0' * (6-len(x)) + x

code_data['종목코드'] = code_data['종목코드'].apply(make_code2)

# %%
# make_price_dataframe 함수를 이용해 가격 데이터를 다 가져와 데이터프레임 만듬
for num, code in enumerate(code_data['종목코드']):
    try:
        print(num, code)
        time.sleep(1)
        try:
            price_df = make_price_dataframe(code, 'day', '1500')
        except requests.exceptions.Timeout:
            time.sleep(60)
            price_df = make_price_dataframe(code, 'day', '1500')
        if num == 0 :
            total_price = price_df
        else:
            total_price = pd.merge(total_price, price_df, how='outer', right_index=True, left_index=True)
    except ValueError:
        continue
    except KeyError:
        continue

total_price
# 엑셀에 저장하기전 날짜 문자열을 판다스의 날짜 타입으로 변환
total_price.index = pd.to_datetime(total_price.index)
total_price.to_excel('가격데이터.xlsx')
# Out:
# 0 060310
# 1 095570
# 2 006840
# 3 054620
# 4 265520
# 5 211270
# 6 027410
# 7 282330
# 8 138930
# 9 001460
# 10 001040
# 11 079160
# 12 035760
# 13 000120
# 14 011150
# 15 097950
# 16 051500
# 17 058820
# 18 023460
# 19 065770
# 20 083660
# 21 000590
# 22 012030
# 23 322780
# 24 016610
# 25 005830
# 26 000990
# 27 139130
# 28 068790
# 29 004840
# 30 241520
# 31 155660
# 32 069730
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-817b2f9debd4> in <module>
#       3     try:
#       4         print(num, code)
# ----> 5         time.sleep(1)
#       6         try:
#       7             price_df = make_price_dataframe(code, 'day', '1500')
#
# KeyboardInterrupt:
